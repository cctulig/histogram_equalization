# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img = cv.imread(r"C:\Users\Noelle\Documents\school\iqp\AI repo\histogram_equalization\algorithm-prototyping\images\test1.png",0)
equ = cv.equalizeHist(img)
res= np.hstack((img,equ))
newImg = cv.imwrite('res.png', res)
imgplot = plt.imshow(res)
plt.subplot(212)
plt.imshow(res, cmap='Greys_r',  interpolation='nearest')
plt.savefig('blkwht.png')
plt.show()
